# %%
import json
import os
import requests
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd
import datetime
import streamlit as st

# %%
# Constants
data_folder = "data/"
metadata_folder = "data/books_metadata/"

# %%
# Helper functions
def read_lines_from_file(file_path):
    """Reads lines from a file and returns them as a set"""
    if os.path.exists(file_path):
        with open(file_path, "r") as file:
            return {line.strip() for line in file if line.strip()}
    return set()

def append_line_to_file(line, file_path):
    """Appends a line such as URL or filename to a file"""
    with open(file_path, "a") as file:
        file.write(f"{line}\n")

# %%
# Functions to read URL from txt file
def read_processed_urls(file_path):
    """Reads the list of processed URLs"""
    if os.path.exists(file_path):
        with open(file_path, "r") as file:
            return [line.strip() for line in file]
    return []

# %%
# Function to download single file
def download_file(url, folder_path):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes
        
        # Ensure folder exists
        os.makedirs(folder_path, exist_ok=True)
        filename = os.path.basename(url)  # Extract filename from URL

        # Construct the full file path
        file_path = os.path.join(folder_path, filename)

        with open(file_path, 'w') as file:
            file.write(response.text)
        print(f'{filename} downloaded successfully and saved to {folder_path}.')
    except requests.RequestException as e:
        print(f'Error downloading {url}: {e}')


# Use ThreadPoolExecutor to download files concurrently
def download_files_concurrently(urls, folder_path, max_workers=5):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(download_file, url, folder_path) for url in urls]
        for future in as_completed(futures):
            future.result()  # Wait for all futures to complete

# %%
# Function to process only new URLs
def process_new_urls (urls_file, processed_file, folder_path):
    """Process new URLs, skip the ones already processed"""
    # Read all URLs from the txt file
    all_urls = read_lines_from_file(urls_file)

    # Read already processed URLs
    already_processed = read_processed_urls(processed_file)
  
    # Filter out already processed URLs
    new_urls = [url for url in all_urls if url not in already_processed]

    if not new_urls:
        print("No new URLs to process.")
        return
    
    # Download the new URLs concurrently
    download_files_concurrently(new_urls, folder_path)


    # Save newly processed URLs to the processed file
    for url in new_urls:
        append_line_to_file(url, processed_file)

# %%
# Run code
process_new_urls(
    urls_file="data/urls.txt",
    processed_file="data/downloaded_urls.txt",
    folder_path="data/books_metadata"
)
# Out:
# libbyjourney-9014207-take-note.json downloaded successfully and saved to data/books_metadata.
# libbyjourney-3391918-a-burst-of-light.json downloaded successfully and saved to data/books_metadata.

# %%
# Convert Unix timestamp
def convert_timestamp(timestamp_ms):
    timestamp_s = timestamp_ms / 1000.0
    return datetime.datetime.fromtimestamp(timestamp_s).strftime('%Y-%m-%d %H:%M:%S')

# %%
# Process single JSON file and return reading journey and highlights data
def process_json(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    
    # Extract relevant parts
    reading_journey = data.get('readingJourney', {})
    highlights = data.get('highlights', [])
    bookmarks = data.get('bookmarks', [])
    
    # Process reading journey
    titles_info = {
        "isbn": reading_journey.get("isbn", ""),
        "titleId": reading_journey.get("titleId", ""),
        "title": reading_journey.get("title", {}).get("text", ""),
        "author": reading_journey.get("author", ""),
        "publisher": reading_journey.get("publisher", ""),
        "cover_url": reading_journey.get("cover", {}).get("url", ""),
        "percent_read": reading_journey.get("percent", 0)
    }
    
    # Process highlights
    highlights_info = [
        {
            "isbn": titles_info["isbn"],
            "timestamp": convert_timestamp(highlight.get("timestamp", 0)),
            "chapter": highlight.get("chapter", ""),
            "percent": highlight.get("percent", 0),
            "color": highlight.get("color", ""),
            "quote": highlight.get("quote", ""),
            "note": highlight.get("note", "")
        }
        for highlight in highlights
    ]

     # Process bookmarks
    bookmarks_info = [
        {
            "isbn": titles_info["isbn"],
            "timestamp": convert_timestamp(bookmark.get("timestamp", 0)),
            "note": bookmark.get("note", "")
        }
        for bookmark in bookmarks
    ]
    
    return titles_info, highlights_info, bookmarks_info

# %%
# Process all JSON files in data folder
def process_all_json_files(folder_path, processed_log="data/processed_files.txt"):
    processed_files = read_lines_from_file(processed_log)
    all_titles = []
    all_highlights = []
    all_bookmarks = []

    # Load previously processed files
    if os.path.exists(processed_log):
        with open(processed_log, "r") as file:
            processed_files = {line.strip() for line in file}
    
    else:
        processed_files = set()
    
    # Flag to track whether new files were processed
    new_files_processed = False

    # Iterate through files in folder
    for filename in os.listdir(folder_path):
        if filename.endswith('.json') and filename not in processed_files:
            file_path = os.path.join(folder_path, filename)
            try:
                titles_info, highlights_info, bookmarks_info = process_json(file_path)
                all_titles.append(titles_info)
                all_highlights.extend(highlights_info)
                all_bookmarks.extend(bookmarks_info)

                # Record this file as processed
                with open(processed_log, "a") as file:
                    file.write(f"{filename}\n")

                # Mark that a new file has been processed
                new_files_processed = True

            except Exception as e:
                print(f"Failed to process {filename}: {e}")
    
    # Only return data if new files were processed
    if new_files_processed:
        return all_titles, all_highlights, all_bookmarks
    else:
        return None, None, None

# %%
def compile_data_to_dataframes(folder_path):
    all_titles, all_highlights, all_bookmarks = process_all_json_files(folder_path)
    
    # Convert lists to DataFrames
    titles_df = pd.DataFrame(all_titles)
    highlights_df = pd.DataFrame(all_highlights)
    bookmarks_df = pd.DataFrame(all_bookmarks)
    
    return titles_df, highlights_df, bookmarks_df

# %%
titles_df, highlights_df, bookmarks_df = compile_data_to_dataframes(metadata_folder)

# %%
titles_df
# Out:
#             isbn titleId             title       author  \
# 0  9780008556167                 Take Note    Toni Tone
# 1  9780486824307          A Burst of Light  Audre Lorde
#
#                   publisher  \
# 0  HarperCollins Publishers
# 1        Dover Publications
#
#                                            cover_url  percent_read
# 0  https://img2.od-cdn.com/ImageType-100/0292-1/{...      1.000001
# 1  https://img2.od-cdn.com/ImageType-100/3082-1/{...      0.997159

# %%
highlights_df
# Out:
#              isbn            timestamp  \
# 0   9780486824307  2024-04-25 19:06:40
# 1   9780486824307  2024-04-25 19:06:40
# 2   9780486824307  2024-04-25 19:05:14
# 3   9780486824307  2024-04-25 19:01:37
# 4   9780486824307  2024-04-25 19:00:51
# 5   9780486824307  2024-04-25 18:51:19
# 6   9780486824307  2024-04-25 07:12:53
# 7   9780486824307  2024-04-25 07:12:53
# 8   9780486824307  2024-04-25 07:09:16
# 9   9780486824307  2024-04-25 07:07:45
# 10  9780486824307  2024-04-25 07:05:06
# 11  9780486824307  2024-04-24 09:59:39
# 12  9780486824307  2024-04-24 09:58:26
# 13  9780486824307  2024-04-24 09:57:18
# 14  9780486824307  2024-04-24 09:55:39
# 15  9780486824307  2024-04-24 09:49:51
# 16  9780486824307  2024-04-24 09:28:34
# 17  9780486824307  2024-04-24 07:48:16
# 18  9780486824307  2024-04-24 07:46:04
# 19  9780486824307  2024-04-22 07:11:55
# 20  9780486824307  2024-04-22 07:05:15
# 21  9780486824307  2024-04-21 07:45:39
# 22  9780486824307  2024-04-20 09:38:18
# ...

# %%
bookmarks_df
# Out:
#             isbn            timestamp  \
# 0  9780008556167  2024-04-17 18:23:51
# 1  9780008556167  2024-04-17 08:23:50
# 2  9780008556167  2024-04-15 18:53:35
# 3  9780008556167  2024-04-15 18:49:44
# 4  9780008556167  2024-04-15 18:33:52
# 5  9780008556167  2024-04-15 08:31:31
# 6  9780486824307  2024-04-17 07:59:31
# 7  9780486824307  2024-04-17 07:57:36
#
#                                                 note
# 0  Outgrowing friendships is a common cause of fr...
# 1   Being nice doesn’t have to mean being agreeable
# 2  Be honest and transparent with overthinkers in...
# 3            Overthinking is the enemy of happiness
# 4  Make sure your opinion of yourself holds the m...
# 5  “You’ve changed” is only a problem if you’ve c...
# 6
# 7

# %%
def save_dataframes_to_csv(titles_df, highlights_df, bookmarks_df, output_dir="./dataframes"):
    """Saves the given DataFrames to CSV files in the specified directory."""
    os.makedirs(output_dir, exist_ok=True)

    try:
        titles_df.to_csv(os.path.join(output_dir, "titles_df.csv"), index=False)
        highlights_df.to_csv(os.path.join(output_dir, "highlights_df.csv"), index=False)
        bookmarks_df.to_csv(os.path.join(output_dir, "bookmarks_df.csv"), index=False)
        print("DataFrames saved successfully.")
    except Exception as e:
        print(f"Error saving DataFrames: {e}")

# %%
def save_dataframes_to_csv(titles_df, highlights_df, bookmarks_df, output_dir="./dataframes"):
    """Saves the given DataFrames to CSV files in the specified directory. Avoids overwriting old dataframes."""
    os.makedirs(output_dir, exist_ok=True)

    def append_and_save(df_new, filename):
        file_path = os.path.join(output_dir, filename)
        
        if os.path.exists(file_path):
            df_existing = pd.read_csv(file_path)
            combined = pd.concat([df_existing, df_new], ignore_index=True)
        else:
            combined = df_new

        # Optional: drop duplicates by primary key, e.g., "titleId" or "timestamp"
        #combined.drop_duplicates(inplace=True)

        combined.to_csv(file_path, index=False)

    try:
        append_and_save(titles_df, "titles_df.csv")
        append_and_save(highlights_df, "highlights_df.csv")
        append_and_save(bookmarks_df, "bookmarks_df.csv")
        print("DataFrames updated and saved successfully.")
    except Exception as e:
        print(f"Error saving DataFrames: {e}")
